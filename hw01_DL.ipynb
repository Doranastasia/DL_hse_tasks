# %% [markdown]
# # Домашняя работа 1
#
#
# ## Описание
#
# В этой домашней работе вы должны применить знания по многослойным нейроным сетям
#
# - Для простоты попробуем обучить сначала однослойный перцептрон
# - Решать будем простую задачу бинарной классификации
# - Датасет игрушечный -  `load_data()` загружает его

# %%
import numpy as np
import torch
import tqdm
from torch import nn
import sklearn
from sklearn.datasets import make_gaussian_quantiles
from sklearn.model_selection import train_test_split
from matplotlib.colors import ListedColormap
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader, TensorDataset
import torch.optim as optim
import copy
import torch.nn.init as init
import torch.nn.functional as F
import pandas as pd
import numpy as np
from sklearn.model_selection import KFold, StratifiedKFold

# %% [markdown]
# ## Загрузка данных

# %%
def load_data(n_samples=500):
    return make_gaussian_quantiles(
        mean=None,
        cov=0.7,
        n_samples=n_samples,
        n_features=2,
        n_classes=2,
        shuffle=True,
        random_state=42,
    )

# %%
gaussian_quantiles = load_data()
X, y = gaussian_quantiles

print(X[:10, :])
print(y[:10])

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)
# Out:
# [[-1.13773727  0.62436053]
#  [-0.75970745 -1.18161805]
#  [-0.82471758  0.42171557]
#  [-0.09398039 -0.18487643]
#  [-0.80731289  0.57399183]
#  [ 0.67980788  1.13471182]
#  [-1.70521733 -0.84342552]
#  [ 1.57461467  1.12565917]
#  [-0.22579357 -0.81889248]
#  [ 0.97317262  0.00856159]]
# [1 1 0 0 1 1 1 1 0 1]

# %%
cm = plt.cm.RdBu
cm_bright = ListedColormap(['#FF0000', '#0000FF'])

def plot_data(X, y, xy_labels=True, label=None, **kwargs):
    X_1 = X[y == 1]
    X_0 = X[y == 0]
    if label is not None:
        plt.scatter(X_1[:, 0], X_1[:, 1], c="blue", s=30, label=label + " (yi=1)", **kwargs)
        plt.scatter(X_0[:, 0], X_0[:, 1], c="red", s=30, label=label + " (yi=0)", **kwargs)
    plt.xticks(())
    plt.yticks(())
    plt.xlim(X[:, 0].min() - 1, X[:, 0].max() + 1)
    plt.ylim(X[:, 1].min() - 1, X[:, 1].max() + 1)

plt.figure(figsize=(6, 6))
plot_data(X_train, y_train, alpha=0.7, label="Train")
plot_data(X_test, y_test, alpha=0.3, label="Valid")
plt.legend(fontsize=13)
plt.tight_layout()

# %% [markdown]
# ## Класс нейросети
#
# Вам необходимо описать простую полносвязную многослойную нейронную сеть

# %%
class NeuralNetwork(nn.Module):
    def __init__(self):
        super().__init__()
        self.layer1 = nn.Linear(2, 8)
        self.act1 = nn.ReLU()
        self.layer2 = nn.Linear(8, 8)
        self.act2 = nn.ReLU()
        self.layer3 = nn.Linear(8, 4)
        self.act3 = nn.ReLU()
        self.layer4 = nn.Linear(4, 2)
        self.act4 = nn.ReLU()
        self.out = nn.Linear(2, 1)
        self.sig = nn.Sigmoid()

    def forward(self, x):
        x = self.act1(self.layer1(x))
        x = self.act2(self.layer2(x))
        x = self.act3(self.layer3(x))
        x = self.act4(self.layer4(x))
        x = self.sig(self.out(x))
        return x

# %% [markdown]
# ##  Функция обучения сети

# %%
def model_train(model, loss_fn, opt, 
          n_epochs, batch_size, lr,
          X_train, y_train, X_val=None, y_val=None):
    
    x_train_loader = DataLoader(X_train, batch_size=batch_size)
    y_train_loader = DataLoader(y_train, batch_size=batch_size)
    x_val_ld = DataLoader(X_val, batch_size=1) if X_val is not None else None
    y_val_ld = DataLoader(y_val, batch_size=1) if y_val is not None else None

    batch_start = torch.arange(0, len(X_train), batch_size)
    # Hold the best model
    best_acc = - np.inf   # init to negative infinity
    best_weights = None
    preds_history = []
    loss_history = []
    for epoch in range(n_epochs):
        model.train()
        with tqdm.tqdm(batch_start, unit="batch", mininterval=0, disable=False) as bar:
            bar.set_description(f"Epoch {epoch}")
            for x_batch, y_batch in zip(x_train_loader, y_train_loader):
                # forward pass
                y_pred = model(x_batch)
                loss_val = loss_fn(y_pred, y_batch)
                loss_history.append(loss_val.item())
                # backward pass
                opt.zero_grad()
                loss_val.backward()
                # update weights
                opt.step()
                # print progress
                acc = (y_pred.round() == y_batch).float().mean()
                bar.set_postfix(
                    loss=float(loss_val),
                    acc=float(acc)
                )
                
#         evaluate accuracy at end of each epoch
        if X_val is not None and y_val is not None:
            model.eval()
            y_pred = model(X_val)
            acc = (y_pred.round() == y_val).float().mean()
            acc = float(acc)
        if acc > best_acc:
            best_acc = acc
            best_weights = copy.deepcopy(model.state_dict())
        if acc > 0.98:
            break
            
    # restore model and return best accuracy
    model.load_state_dict(best_weights)
    
    return best_acc, loss_history

# %% [markdown]
# ### Обучите сеть
#
# Обучите сеть три раза - с тремя разными оптимизиторами
# Не забудьте переинициализировать сеть заного перед каждой загрузкой. Убедитесь, что вы верно передали параметры сети в оптимизатор
#
# **Подсказка** Лучше объявить три независимых объекта - модель1, модель2 и модель3

# %%
X_train_torch = torch.from_numpy(X_train).float()
y_train_torch = torch.from_numpy(y_train).float().reshape(-1, 1)
X_valid_torch = torch.from_numpy(X_test).float()
y_valid_torch = torch.from_numpy(y_test).float().reshape(-1, 1)

# %%
model1 = NeuralNetwork()
model2 = NeuralNetwork()
model3 = NeuralNetwork()

loss_SGD = []
loss_Adam = []
loss_rmsprop = []

optims = {
    'optim1': optim.SGD(model1.parameters(), lr = 0.03),
    'optim2': optim.Adam(model2.parameters(), lr = 0.01),
    'optim3': optim.RMSprop(model3.parameters(), lr = 0.001)
}

results = {}

for opt_name, opt in optims.items():
    if opt_name == 'optim1':
        model = model1
    elif opt_name == 'optim2':
        model = model2
    else:
        model = model3
    
    results[opt_name], lh = model_train(model, 
                                    nn.BCELoss(), 
                                    opt, 
                                    120, 
                                    30, 
                                    0.01, 
                                    X_train_torch, 
                                    y_train_torch, 
                                    X_valid_torch, 
                                    y_valid_torch)
    if opt_name == 'optim1':
        loss_SGD = lh
    elif opt_name == 'optim2':
        loss_Adam = lh
    else:
        loss_rmsprop = lh
# Out:
# Epoch 0:   0%|                                                           | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.63]
# Epoch 1:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.635]
# Epoch 2:   0%|                                                           | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.64]
# Epoch 3:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.644]
# Epoch 4:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.648]
# Epoch 5:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.653]
# Epoch 6:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.656]
# Epoch 7:   0%|                                                           | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.66]
# Epoch 8:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.663]
# Epoch 9:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.666]
# Epoch 10:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.668]
# Epoch 11:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.671]
# Epoch 12:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.673]
# Epoch 13:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.675]
# Epoch 14:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.676]
# Epoch 15:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.678]
# Epoch 16:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.679]
# Epoch 17:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.68]
# Epoch 18:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.681]
# Epoch 19:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.682]
# Epoch 20:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.683]
# Epoch 21:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.684]
# Epoch 22:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.684]
# Epoch 23:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.685]
# Epoch 24:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.685]
# Epoch 25:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.686]
# Epoch 26:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.686]
# Epoch 27:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.686]
# Epoch 28:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.686]
# Epoch 29:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.687]
# Epoch 30:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.687]
# Epoch 31:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.687]
# Epoch 32:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.687]
# Epoch 33:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.687]
# Epoch 34:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.687]
# Epoch 35:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 36:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 37:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 38:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 39:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 40:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 41:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 42:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 43:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 44:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 45:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 46:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 47:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 48:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 49:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 50:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 51:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 52:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 53:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 54:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 55:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 56:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 57:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 58:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 59:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 60:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 61:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 62:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 63:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 64:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 65:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 66:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 67:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 68:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 69:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 70:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 71:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 72:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.689]
# Epoch 73:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.689]
# Epoch 74:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.689]
# Epoch 75:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.689]
# Epoch 76:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.689]
# Epoch 77:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.689]
# Epoch 78:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.689]
# Epoch 79:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.689]
# Epoch 80:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.689]
# Epoch 81:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.689]
# Epoch 82:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.689]
# Epoch 83:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.689]
# Epoch 84:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.689]
# Epoch 85:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.689]
# Epoch 86:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.689]
# Epoch 87:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.689]
# Epoch 88:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.689]
# Epoch 89:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.689]
# Epoch 90:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.689]
# Epoch 91:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.689]
# Epoch 92:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.689]
# Epoch 93:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.689]
# Epoch 94:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.689]
# Epoch 95:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.689]
# Epoch 96:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.689]
# Epoch 97:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.689]
# Epoch 98:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.689]
# Epoch 99:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.689]
# Epoch 100:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.8, loss=0.689]
# Epoch 101:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.689]
# Epoch 102:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.689]
# Epoch 103:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.689]
# Epoch 104:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.6, loss=0.689]
# Epoch 105:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.6, loss=0.689]
# Epoch 106:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.6, loss=0.689]
# Epoch 107:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.6, loss=0.689]
# Epoch 108:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.6, loss=0.689]
# Epoch 109:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.6, loss=0.688]
# Epoch 110:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.5, loss=0.688]
# Epoch 111:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.5, loss=0.688]
# Epoch 112:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.5, loss=0.688]
# Epoch 113:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.5, loss=0.688]
# Epoch 114:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.5, loss=0.688]
# Epoch 115:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.5, loss=0.688]
# Epoch 116:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.5, loss=0.688]
# Epoch 117:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.5, loss=0.688]
# Epoch 118:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.5, loss=0.688]
# Epoch 119:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.5, loss=0.688]
# Epoch 0:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=0.3, loss=0.761]
# Epoch 1:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.584]
# Epoch 2:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=0.8, loss=0.431]
# Epoch 3:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.267]
# Epoch 4:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.203]
# Epoch 5:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.167]
# Epoch 6:   0%|                                                           | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.14]
# Epoch 7:   0%|                                                             | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.12]
# Epoch 8:   0%|                                                              | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.1]
# Epoch 0:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.641]
# Epoch 1:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.642]
# Epoch 2:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.644]
# Epoch 3:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.645]
# Epoch 4:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.646]
# Epoch 5:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=0.8, loss=0.645]
# Epoch 6:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.643]
# Epoch 7:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.638]
# Epoch 8:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=0.8, loss=0.632]
# Epoch 9:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=0.8, loss=0.627]
# Epoch 10:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.8, loss=0.619]
# Epoch 11:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.612]
# Epoch 12:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.602]
# Epoch 13:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.591]
# Epoch 14:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.579]
# Epoch 15:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.567]
# Epoch 16:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.554]
# Epoch 17:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.54]
# Epoch 18:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.8, loss=0.526]
# Epoch 19:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.8, loss=0.511]
# Epoch 20:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.496]
# Epoch 21:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.481]
# Epoch 22:   0%|                                                           | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.465]
# Epoch 23:   0%|                                                            | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.45]
# Epoch 24:   0%|                                                           | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.436]
# Epoch 25:   0%|                                                           | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.421]
# Epoch 26:   0%|                                                           | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.409]
# Epoch 27:   0%|                                                           | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.397]
# Epoch 28:   0%|                                                           | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.386]
# Epoch 29:   0%|                                                           | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.375]
# Epoch 30:   0%|                                                           | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.366]
# Epoch 31:   0%|                                                           | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.356]
# Epoch 32:   0%|                                                           | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.348]
# Epoch 33:   0%|                                                           | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.339]
# Epoch 34:   0%|                                                           | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.332]
# Epoch 35:   0%|                                                           | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.323]
# Epoch 36:   0%|                                                           | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.316]
# Epoch 37:   0%|                                                           | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.308]
# Epoch 38:   0%|                                                           | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.301]
# Epoch 39:   0%|                                                           | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.294]
# Epoch 40:   0%|                                                           | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.287]
# Epoch 41:   0%|                                                           | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.284]
# Epoch 42:   0%|                                                            | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.28]
# Epoch 43:   0%|                                                           | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.277]
# Epoch 44:   0%|                                                           | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.273]
# Epoch 45:   0%|                                                           | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.269]
# Epoch 46:   0%|                                                           | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.267]
# Epoch 47:   0%|                                                           | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.264]
# Epoch 48:   0%|                                                           | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.262]
# Epoch 49:   0%|                                                            | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.26]
# Epoch 50:   0%|                                                           | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.258]
# Epoch 51:   0%|                                                           | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.256]
# Epoch 52:   0%|                                                           | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.254]
# Epoch 53:   0%|                                                           | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.252]
# Epoch 54:   0%|                                                            | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.25]
# Epoch 55:   0%|                                                           | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.248]
# Epoch 56:   0%|                                                           | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.247]
# Epoch 57:   0%|                                                           | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.244]
# Epoch 58:   0%|                                                           | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.242]
# Epoch 59:   0%|                                                            | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.24]
# Epoch 60:   0%|                                                           | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.238]
# Epoch 61:   0%|                                                           | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.235]
# Epoch 62:   0%|                                                           | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.233]
# Epoch 63:   0%|                                                           | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.231]
# Epoch 64:   0%|                                                            | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.23]
# Epoch 65:   0%|                                                           | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.228]
# Epoch 66:   0%|                                                           | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.226]
# Epoch 67:   0%|                                                           | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.224]
# Epoch 68:   0%|                                                           | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.222]
# Epoch 69:   0%|                                                           | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.221]
# Epoch 70:   0%|                                                           | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.219]
# Epoch 71:   0%|                                                           | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.217]
# Epoch 72:   0%|                                                           | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.215]
# Epoch 73:   0%|                                                           | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.213]
# Epoch 74:   0%|                                                            | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.21]
# Epoch 75:   0%|                                                           | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.209]
# Epoch 76:   0%|                                                           | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.207]
# Epoch 77:   0%|                                                           | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.205]
# Epoch 78:   0%|                                                           | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.203]
# Epoch 79:   0%|                                                           | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.201]
# Epoch 80:   0%|                                                           | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.199]
# Epoch 81:   0%|                                                           | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.197]
# Epoch 82:   0%|                                                           | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.195]
# Epoch 83:   0%|                                                           | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.194]
# Epoch 84:   0%|                                                           | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.191]
# Epoch 85:   0%|                                                           | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.189]
# Epoch 86:   0%|                                                           | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.187]
# Epoch 87:   0%|                                                           | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.185]
# Epoch 88:   0%|                                                           | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.184]
# Epoch 89:   0%|                                                           | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.182]
# Epoch 90:   0%|                                                            | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.18]
# Epoch 91:   0%|                                                           | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.177]
# Epoch 92:   0%|                                                           | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.177]
# Epoch 93:   0%|                                                           | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.175]
# Epoch 94:   0%|                                                           | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.173]
# Epoch 95:   0%|                                                           | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.172]
# Epoch 96:   0%|                                                            | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.17]
# Epoch 97:   0%|                                                           | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.169]
# Epoch 98:   0%|                                                           | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.167]
# Epoch 99:   0%|                                                           | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.165]
# Epoch 100:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.163]
# Epoch 101:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.161]
# Epoch 102:   0%|                                                           | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.16]
# Epoch 103:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.158]
# Epoch 104:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.156]
# Epoch 105:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.155]
# Epoch 106:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.152]
# Epoch 107:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.152]
# Epoch 108:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.149]
# Epoch 109:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.149]
# Epoch 110:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.146]
# Epoch 111:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.146]
# Epoch 112:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.143]
# Epoch 113:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.142]
# Epoch 114:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.141]
# Epoch 115:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.138]
# Epoch 116:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.137]
# Epoch 117:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.136]
# Epoch 118:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.136]
# Epoch 119:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.134]

# %%
results
# Out:
# {'optim1': 0.7400000095367432,
#  'optim2': 0.9900000095367432,
#  'optim3': 0.9700000286102295}

# %% [markdown]
# ### А теперь посмотрим на графики лоссов

# %%
plt.plot(loss_SGD, label = "Stochastic Gradient Descent")
plt.plot(loss_Adam, label = "Adam Optimizer")
plt.plot(loss_rmsprop, label = 'RMSProp Optimizer')
plt.xlabel('epoch')
plt.ylabel('Cost/ total loss')
plt.legend()
plt.show()

# %% [markdown]
# ### Инициализация

# %% [markdown]
# Теперь проинициализируйте веса в вашей модели: случайно и Ксавьером. Сравните результат

# %%
# xavier
class NeuralNetworkXa(nn.Module):
    def __init__(self):
        super().__init__()        
        self.fc1 = nn.Linear(2, 8)
        self.fc2 = nn.Linear(8, 8)
        self.fc3 = nn.Linear(8, 4)
        self.fc4 = nn.Linear(4, 1)
        
        nn.init.xavier_normal_(self.fc1.weight)
        nn.init.zeros_(self.fc1.bias)
        
        nn.init.xavier_normal_(self.fc2.weight)
        nn.init.zeros_(self.fc2.bias)
        
        nn.init.xavier_normal_(self.fc3.weight)
        nn.init.zeros_(self.fc3.bias)
        
        nn.init.xavier_normal_(self.fc4.weight)
        nn.init.zeros_(self.fc4.bias)
        
    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = F.relu(self.fc3(x))
        x = torch.sigmoid(self.fc4(x)) 
        return x

# %%
model1x = NeuralNetworkXa()
model2x = NeuralNetworkXa()
model3x = NeuralNetworkXa()


optims_x = {
    'optim1': optim.SGD(model1x.parameters(), lr = 0.03),
    'optim2': optim.Adam(model2x.parameters(), lr = 0.01),
    'optim3': optim.RMSprop(model3x.parameters(), lr = 0.001)
}

result_random = {}

for opt_name, opt in optims_x.items():
    if opt_name == 'optim1':
        model = model1x
    elif opt_name == 'optim2':
        model = model2x
    else:
        model = model3x
    
    result_random[opt_name], lh = model_train(model, 
                                    nn.BCELoss(), 
                                    opt, 
                                    120, 
                                    30, 
                                    0.01, 
                                    X_train_torch, 
                                    y_train_torch, 
                                    X_valid_torch, 
                                    y_valid_torch)
    if opt_name == 'optim1':
        loss_SGD = lh
    elif opt_name == 'optim2':
        loss_Adam = lh
    else:
        loss_rmsprop = lh
# Out:
# Epoch 0:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.671]
# Epoch 1:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.669]
# Epoch 2:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.666]
# Epoch 3:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.663]
# Epoch 4:   0%|                                                           | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.66]
# Epoch 5:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.657]
# Epoch 6:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=0.8, loss=0.654]
# Epoch 7:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=0.8, loss=0.649]
# Epoch 8:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.645]
# Epoch 9:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.641]
# Epoch 10:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.635]
# Epoch 11:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.626]
# Epoch 12:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.613]
# Epoch 13:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.605]
# Epoch 14:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.594]
# Epoch 15:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.582]
# Epoch 16:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.572]
# Epoch 17:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.56]
# Epoch 18:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.548]
# Epoch 19:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.535]
# Epoch 20:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.521]
# Epoch 21:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.507]
# Epoch 22:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.486]
# Epoch 23:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.474]
# Epoch 24:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.464]
# Epoch 25:   0%|                                                           | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.452]
# Epoch 26:   0%|                                                           | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.437]
# Epoch 27:   0%|                                                           | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.422]
# Epoch 28:   0%|                                                           | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.407]
# Epoch 29:   0%|                                                           | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.392]
# Epoch 30:   0%|                                                           | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.376]
# Epoch 31:   0%|                                                           | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.359]
# Epoch 32:   0%|                                                           | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.343]
# Epoch 33:   0%|                                                           | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.327]
# Epoch 34:   0%|                                                           | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.311]
# Epoch 35:   0%|                                                           | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.297]
# Epoch 36:   0%|                                                           | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.283]
# Epoch 37:   0%|                                                           | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.269]
# Epoch 38:   0%|                                                           | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.257]
# Epoch 39:   0%|                                                           | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.245]
# Epoch 40:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.234]
# Epoch 41:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.223]
# Epoch 42:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.212]
# Epoch 43:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.203]
# Epoch 44:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.194]
# Epoch 45:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.185]
# Epoch 46:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.178]
# Epoch 47:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.171]
# Epoch 48:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.164]
# Epoch 49:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.158]
# Epoch 50:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.153]
# Epoch 51:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.148]
# Epoch 52:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.143]
# Epoch 53:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.138]
# Epoch 54:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.134]
# Epoch 55:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.13]
# Epoch 56:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.127]
# Epoch 57:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.124]
# Epoch 58:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.121]
# Epoch 59:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.119]
# Epoch 60:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.116]
# Epoch 61:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.114]
# Epoch 62:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.111]
# Epoch 63:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.109]
# Epoch 64:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.107]
# Epoch 65:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.105]
# Epoch 66:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.104]
# Epoch 67:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.102]
# Epoch 68:   0%|                                                           | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.1]
# Epoch 69:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.099]
# Epoch 70:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.0976]
# Epoch 71:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.0963]
# Epoch 72:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.095]
# Epoch 73:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.0939]
# Epoch 74:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.0934]
# Epoch 75:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.0924]
# Epoch 76:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.0911]
# Epoch 77:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.0902]
# Epoch 78:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.0893]
# Epoch 79:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.0885]
# Epoch 80:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.0876]
# Epoch 81:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.0869]
# Epoch 82:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.0861]
# Epoch 83:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.0854]
# Epoch 84:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.0848]
# Epoch 85:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.0842]
# Epoch 86:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.0835]
# Epoch 87:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.0832]
# Epoch 88:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.0829]
# Epoch 89:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.0825]
# Epoch 90:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.082]
# Epoch 91:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.0817]
# Epoch 92:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.0813]
# Epoch 93:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.081]
# Epoch 94:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.0808]
# Epoch 95:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.0805]
# Epoch 96:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.0805]
# Epoch 97:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.0802]
# Epoch 98:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.08]
# Epoch 99:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.0798]
# Epoch 100:   0%|                                                       | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.0795]
# Epoch 101:   0%|                                                       | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.0793]
# Epoch 102:   0%|                                                       | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.0792]
# Epoch 103:   0%|                                                       | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.0791]
# Epoch 104:   0%|                                                       | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.0788]
# Epoch 105:   0%|                                                       | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.0787]
# Epoch 106:   0%|                                                       | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.0786]
# Epoch 107:   0%|                                                       | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.0785]
# Epoch 108:   0%|                                                       | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.0786]
# Epoch 109:   0%|                                                       | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.0785]
# Epoch 110:   0%|                                                       | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.0786]
# Epoch 111:   0%|                                                       | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.0784]
# Epoch 112:   0%|                                                       | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.0784]
# Epoch 113:   0%|                                                       | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.0783]
# Epoch 114:   0%|                                                       | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.0785]
# Epoch 115:   0%|                                                       | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.0783]
# Epoch 116:   0%|                                                       | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.0782]
# Epoch 117:   0%|                                                       | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.0782]
# Epoch 118:   0%|                                                       | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.0782]
# Epoch 119:   0%|                                                       | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.0783]
# Epoch 0:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.438]
# Epoch 1:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.359]
# Epoch 2:   0%|                                                            | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.267]
# Epoch 3:   0%|                                                            | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.146]
# Epoch 4:   0%|                                                           | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.0934]
# Epoch 5:   0%|                                                           | 0/14 [00:00<?, ?batch/s, acc=1, loss=0.0542]
# Epoch 0:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=0.6, loss=0.647]
# Epoch 1:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.627]
# Epoch 2:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.618]
# Epoch 3:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.608]
# Epoch 4:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.598]
# Epoch 5:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=0.8, loss=0.585]
# Epoch 6:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.573]
# Epoch 7:   0%|                                                           | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.56]
# Epoch 8:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.547]
# Epoch 9:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.534]
# Epoch 10:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.52]
# Epoch 11:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.505]
# Epoch 12:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.49]
# Epoch 13:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.475]
# Epoch 14:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.46]
# Epoch 15:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.444]
# Epoch 16:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.43]
# Epoch 17:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.416]
# Epoch 18:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.402]
# Epoch 19:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.388]
# Epoch 20:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.375]
# Epoch 21:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.361]
# Epoch 22:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.349]
# Epoch 23:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.336]
# Epoch 24:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.325]
# Epoch 25:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.313]
# Epoch 26:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.302]
# Epoch 27:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.291]
# Epoch 28:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.281]
# Epoch 29:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.27]
# Epoch 30:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.26]
# Epoch 31:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.25]
# Epoch 32:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.24]
# Epoch 33:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.23]

# %%
result_random
# Out:
# {'optim1': 0.9700000286102295,
#  'optim2': 0.9900000095367432,
#  'optim3': 0.9900000095367432}

# %%
plt.plot(loss_SGD, label = "Stochastic Gradient Descent")
plt.plot(loss_Adam, label = "Adam Optimizer")
plt.plot(loss_rmsprop, label = 'RMSProp Optimizer')
plt.xlabel('epoch')
plt.ylabel('Cost/ total loss')
plt.legend()
plt.show()

# %%
# random
class NeuralNetworkRand(nn.Module):
    def __init__(self):
        super().__init__()
        
        self.fc1 = nn.Linear(2, 8)
        self.fc2 = nn.Linear(8, 8)
        self.fc3 = nn.Linear(8, 4)
        self.fc4 = nn.Linear(4, 1)
  
        nn.init.normal_(self.fc1.weight, mean=0, std=0.01)
        nn.init.normal_(self.fc1.bias, mean=0, std=0.01)
        
        nn.init.normal_(self.fc2.weight, mean=0, std=0.01)
        nn.init.normal_(self.fc2.bias, mean=0, std=0.01)
        
        nn.init.normal_(self.fc3.weight, mean=0, std=0.01)
        nn.init.normal_(self.fc3.bias, mean=0, std=0.01)
        
        nn.init.normal_(self.fc4.weight, mean=0, std=0.01)
        nn.init.normal_(self.fc4.bias, mean=0, std=0.01)
        
    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = F.relu(self.fc3(x))
        x = torch.sigmoid(self.fc4(x)) 
        return x

# %%
model1r = NeuralNetworkRand()
model2r = NeuralNetworkRand()
model3r = NeuralNetworkRand()


optims_rand = {
    'optim1': optim.SGD(model1r.parameters(), lr = 0.03),
    'optim2': optim.Adam(model2r.parameters(), lr = 0.01),
    'optim3': optim.RMSprop(model3r.parameters(), lr = 0.001)
}

result_random = {}

for opt_name, opt in optims_rand.items():
    if opt_name == 'optim1':
        model = model1r
    elif opt_name == 'optim2':
        model = model2r
    else:
        model = model3r
    
    result_random[opt_name], lh = model_train(model, 
                                    nn.BCELoss(), 
                                    opt, 
                                    120, 
                                    30, 
                                    0.01, 
                                    X_train_torch, 
                                    y_train_torch, 
                                    X_valid_torch, 
                                    y_valid_torch)
    if opt_name == 'optim1':
        loss_SGD = lh
    elif opt_name == 'optim2':
        loss_Adam = lh
    else:
        loss_rmsprop = lh
# Out:
# Epoch 0:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=0.3, loss=0.694]
# Epoch 1:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=0.3, loss=0.694]
# Epoch 2:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.693]
# Epoch 3:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.692]
# Epoch 4:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.692]
# Epoch 5:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.692]
# Epoch 6:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.691]
# Epoch 7:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.691]
# Epoch 8:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.691]
# Epoch 9:   0%|                                                           | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.69]
# Epoch 10:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.69]
# Epoch 11:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.69]
# Epoch 12:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.69]
# Epoch 13:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.69]
# Epoch 14:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.689]
# Epoch 15:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.689]
# Epoch 16:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.689]
# Epoch 17:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.689]
# Epoch 18:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.689]
# Epoch 19:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.689]
# Epoch 20:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.689]
# Epoch 21:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.689]
# Epoch 22:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.689]
# Epoch 23:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.689]
# Epoch 24:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.689]
# Epoch 25:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.689]
# Epoch 26:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 27:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 28:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 29:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 30:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 31:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 32:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 33:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 34:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 35:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 36:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 37:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 38:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 39:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 40:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 41:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 42:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 43:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 44:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 45:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 46:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 47:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 48:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 49:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 50:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 51:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 52:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 53:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 54:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 55:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 56:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 57:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 58:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 59:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 60:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 61:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 62:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 63:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 64:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 65:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 66:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 67:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 68:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 69:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 70:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 71:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 72:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 73:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 74:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 75:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 76:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 77:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 78:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 79:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 80:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 81:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 82:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 83:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 84:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 85:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 86:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 87:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 88:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 89:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 90:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 91:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 92:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 93:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 94:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 95:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 96:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 97:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 98:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 99:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 100:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 101:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 102:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 103:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 104:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 105:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 106:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 107:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 108:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 109:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 110:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 111:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 112:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 113:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 114:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 115:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 116:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 117:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 118:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 119:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 0:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=0.3, loss=0.698]
# Epoch 1:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=0.3, loss=0.694]
# Epoch 2:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.691]
# Epoch 3:   0%|                                                           | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.69]
# Epoch 4:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.689]
# Epoch 5:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 6:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 7:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 8:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 9:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 10:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 11:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 12:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 13:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 14:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 15:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 16:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 17:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 18:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 19:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 20:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 21:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 22:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 23:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 24:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 25:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 26:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 27:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 28:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 29:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 30:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 31:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 32:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 33:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 34:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 35:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 36:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 37:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 38:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 39:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 40:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 41:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 42:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 43:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 44:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 45:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 46:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 47:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 48:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 49:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 50:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 51:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 52:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 53:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 54:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 55:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 56:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 57:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 58:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 59:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 60:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 61:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 62:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 63:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 64:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 65:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 66:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 67:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 68:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 69:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 70:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 71:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 72:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 73:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 74:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 75:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 76:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 77:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 78:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 79:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 80:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 81:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 82:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 83:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 84:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 85:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 86:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 87:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 88:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 89:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 90:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 91:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 92:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 93:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 94:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 95:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 96:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 97:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 98:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 99:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 100:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 101:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 102:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 103:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 104:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 105:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 106:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 107:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 108:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 109:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 110:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 111:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 112:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 113:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 114:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 115:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 116:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 117:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 118:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 119:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 0:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=0.3, loss=0.693]
# Epoch 1:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.693]
# Epoch 2:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.692]
# Epoch 3:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.692]
# Epoch 4:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.691]
# Epoch 5:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.689]
# Epoch 6:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.688]
# Epoch 7:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.685]
# Epoch 8:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.682]
# Epoch 9:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.678]
# Epoch 10:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.674]
# Epoch 11:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.669]
# Epoch 12:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.664]
# Epoch 13:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.658]
# Epoch 14:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.7, loss=0.652]
# Epoch 15:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.8, loss=0.646]
# Epoch 16:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.8, loss=0.639]
# Epoch 17:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.8, loss=0.631]
# Epoch 18:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.8, loss=0.624]
# Epoch 19:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.8, loss=0.616]
# Epoch 20:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.8, loss=0.608]
# Epoch 21:   0%|                                                           | 0/14 [00:00<?, ?batch/s, acc=0.8, loss=0.6]
# Epoch 22:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.8, loss=0.591]
# Epoch 23:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.8, loss=0.581]
# Epoch 24:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=0.8, loss=0.57]
# Epoch 25:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.8, loss=0.559]
# Epoch 26:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.8, loss=0.549]
# Epoch 27:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.8, loss=0.539]
# Epoch 28:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.8, loss=0.528]
# Epoch 29:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.8, loss=0.519]
# Epoch 30:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=0.8, loss=0.51]
# Epoch 31:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.8, loss=0.501]
# Epoch 32:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.8, loss=0.492]
# Epoch 33:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.8, loss=0.485]
# Epoch 34:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.8, loss=0.477]
# Epoch 35:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.8, loss=0.469]
# Epoch 36:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.8, loss=0.461]
# Epoch 37:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.8, loss=0.453]
# Epoch 38:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.8, loss=0.445]
# Epoch 39:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.8, loss=0.437]
# Epoch 40:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=0.8, loss=0.43]
# Epoch 41:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.8, loss=0.424]
# Epoch 42:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.8, loss=0.418]
# Epoch 43:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.8, loss=0.413]
# Epoch 44:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.8, loss=0.408]
# Epoch 45:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.8, loss=0.404]
# Epoch 46:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.8, loss=0.399]
# Epoch 47:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.8, loss=0.394]
# Epoch 48:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.8, loss=0.389]
# Epoch 49:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.8, loss=0.384]
# Epoch 50:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.8, loss=0.381]
# Epoch 51:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.8, loss=0.377]
# Epoch 52:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.8, loss=0.374]
# Epoch 53:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=0.8, loss=0.37]
# Epoch 54:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.8, loss=0.366]
# Epoch 55:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.8, loss=0.363]
# Epoch 56:   0%|                                                          | 0/14 [00:00<?, ?batch/s, acc=0.8, loss=0.36]
# Epoch 57:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.8, loss=0.357]
# Epoch 58:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.8, loss=0.354]
# Epoch 59:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.8, loss=0.351]
# Epoch 60:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.8, loss=0.348]
# Epoch 61:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.8, loss=0.346]
# Epoch 62:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.343]
# Epoch 63:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.341]
# Epoch 64:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.338]
# Epoch 65:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.335]
# Epoch 66:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.332]
# Epoch 67:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.329]
# Epoch 68:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.327]
# Epoch 69:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.325]
# Epoch 70:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.322]
# Epoch 71:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.319]
# Epoch 72:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.316]
# Epoch 73:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.314]
# Epoch 74:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.311]
# Epoch 75:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.308]
# Epoch 76:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.304]
# Epoch 77:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.301]
# Epoch 78:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.299]
# Epoch 79:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.295]
# Epoch 80:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.291]
# Epoch 81:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.289]
# Epoch 82:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.288]
# Epoch 83:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.287]
# Epoch 84:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.286]
# Epoch 85:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.285]
# Epoch 86:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.283]
# Epoch 87:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.281]
# Epoch 88:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.278]
# Epoch 89:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.277]
# Epoch 90:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.275]
# Epoch 91:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.274]
# Epoch 92:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.275]
# Epoch 93:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.276]
# Epoch 94:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.277]
# Epoch 95:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.276]
# Epoch 96:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.276]
# Epoch 97:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.275]
# Epoch 98:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.274]
# Epoch 99:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.273]
# Epoch 100:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.267]
# Epoch 101:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.248]
# Epoch 102:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.227]
# Epoch 103:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.216]
# Epoch 104:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.209]
# Epoch 105:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.201]
# Epoch 106:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.195]
# Epoch 107:   0%|                                                         | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.19]
# Epoch 108:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.185]
# Epoch 109:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.181]
# Epoch 110:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.179]
# Epoch 111:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.176]
# Epoch 112:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.175]
# Epoch 113:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.173]
# Epoch 114:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.171]
# Epoch 115:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.169]
# Epoch 116:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.167]
# Epoch 117:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.164]
# Epoch 118:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.163]
# Epoch 119:   0%|                                                        | 0/14 [00:00<?, ?batch/s, acc=0.9, loss=0.161]

# %%
result_random
# Out:
# {'optim1': 0.5099999904632568,
#  'optim2': 0.5099999904632568,
#  'optim3': 0.9399999976158142}

# %%
plt.plot(loss_SGD, label = "Stochastic Gradient Descent")
plt.plot(loss_Adam, label = "Adam Optimizer")
plt.plot(loss_rmsprop, label = 'RMSProp Optimizer')
plt.xlabel('epoch')
plt.ylabel('Cost/ total loss')
plt.legend()
plt.show()

# %% [markdown]
# ## А теперь решите многоклассовую проблему

# %% [markdown]
# Продемонстрируйте свои знания - решите более сложную проблему
# Попробуйте разные инициализации, методы оптимизации и кол-во нейронов.
#
# Найдите лучшие параметры через KFold

# %%
points = torch.rand(5000,2)
target = []
for p in points:
    if p[0]>0.2 and p[1]>0.4:
        target.append(1)
    elif p[0]<0.2 and p[1]<0.6:
        target.append(2)
    elif p[0]>0.2 and p[0]<0.8 and p[1] < 0.5:
        target.append(3)
    else:
        target.append(0)
        
target = torch.tensor(target) 
data = torch.cat((points, target.unsqueeze(1)), dim=1)

train = data[:800]
valid = data[800:900]
test = data[900:]

plt.scatter(data[:,0],data[:,1],c = data[:,2])
plt.show()

# %%
class AdvancedModel(nn.Module):
    def __init__(self):
        super(AdvancedModel, self).__init__()
        self.fc1 = nn.Linear(2, 10)
        self.relu1 = nn.ReLU()
        self.fc2 = nn.Linear(10, 8)
        self.relu2 = nn.ReLU()
        self.fc3 = nn.Linear(8, 10)
        self.relu3 = nn.ReLU()
        self.fc4 = nn.Linear(10, 4)  # меняем на 4, так как у нас 4 класса
        
    def forward(self, X):
        x = self.relu1(self.fc1(X))
        x = self.relu2(self.fc2(x))
        x = self.relu3(self.fc3(x))
        predictions = F.softmax(self.fc4(x), dim=1)  # софтмакс для получения вероятностей
        return predictions

# %%
def model_train(model, n_epochs, batch_size, optimizer, criterion,
                X_train, y_train, X_val, y_val):
    
    batch_start = torch.arange(0, len(X_train), batch_size)

    model.train()
    for epoch in range(n_epochs):
        for start in batch_start:
            X_batch = X_train[start:start+batch_size]
            y_batch = y_train[start:start+batch_size]
            optimizer.zero_grad()
            out = model(X_batch)
            loss = criterion(out, y_batch.long())  # long, так как используем CrossEntropyLoss
            loss.backward()
            optimizer.step()

    model.eval()
    with torch.no_grad():  # не надо вычислять градиент, тк для текущей задачи не надо это
        out = model(X_val) 
        np, predicted = torch.max(out, 1) # получение индекса класса с наибольшей вероятностью: np - значения максимумов, predicted - индексы классов с наибольшими значениями, 1 - ось
        acc = (predicted == y_val.long()).float().mean().item()
    return acc

# %%
# поделим на 5 частей
kfold = StratifiedKFold(n_splits = 10, shuffle = True)
model_k = AdvancedModel()
opt = optim.Adam(model_k.parameters(), lr = 0.01)

accuracies = []
for train_indices, test_indices in kfold.split(points, target):   
    acc = model_train(model_k, 
                      50, 
                      10, 
                      opt, 
                      nn.CrossEntropyLoss(),
                      points[train_indices], target[train_indices],
                      points[test_indices], target[test_indices])
    
    print("Accuracy: %.2f" % acc)
    accuracies.append(acc)

# проведем оценку модели
mean_accuracy = np.mean(accuracies)
std_accuracy = np.std(accuracies)
print("Overall accuracy for AdvancedModel: %.2f%% (+/- %.2f%%))" % (mean_accuracy*100, std_accuracy*100))
# Out:
# Accuracy: 0.86
# Accuracy: 0.88
# Accuracy: 0.87
# Accuracy: 0.84
# Accuracy: 0.89
# Accuracy: 0.89
# Accuracy: 0.88
# Accuracy: 0.90
# Accuracy: 0.87
# Accuracy: 0.88
# Overall accuracy for AdvancedModel: 87.40% (+/- 1.64%))

# %% [markdown]
# ## (Почти) Боевая задача
#
# Перед вами датасет с классификацией алкоголя. Продемонстрируйте свои знания и решите задачу многоклассовой классификации

# %%
df = sklearn.datasets.load_wine(as_frame=True)
df = df.frame
df.head()
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline  target
# 0                          3.92   1065.0       0
# 1                          3.40   1050.0       0
# 2                          3.17   1185.0       0
# 3                          3.45   1480.0       0
# 4                          2.93    735.0       0

# %%
# преобразую целевую переменную 
target = pd.get_dummies(df['target'])
target
# Out:
#      0  1  2
# 0    1  0  0
# 1    1  0  0
# 2    1  0  0
# 3    1  0  0
# 4    1  0  0
# ..  .. .. ..
# 173  0  0  1
# 174  0  0  1
# 175  0  0  1
# 176  0  0  1
# 177  0  0  1
#
# [178 rows x 3 columns]

# %%
df.drop(columns=['target'], inplace=True)

# нормализуем признаки
df_normalized = (df - df.mean())/df.std()
df_normalized
# Out:
#       alcohol  malic_acid       ash  alcalinity_of_ash  magnesium  \
# 0    1.514341   -0.560668  0.231400          -1.166303   1.908522
# 1    0.245597   -0.498009 -0.825667          -2.483841   0.018094
# 2    0.196325    0.021172  1.106214          -0.267982   0.088110
# 3    1.686791   -0.345835  0.486554          -0.806975   0.928300
# 4    0.294868    0.227053  1.835226           0.450674   1.278379
# ..        ...         ...       ...                ...        ...
# 173  0.873810    2.966176  0.304301           0.300954  -0.331985
# 174  0.491955    1.408636  0.413653           1.049555   0.158126
# 175  0.331822    1.739837 -0.388260           0.151234   1.418411
# 176  0.208643    0.227053  0.012696           0.151234   1.418411
# 177  1.391162    1.578712  1.361368           1.498716  -0.261969
#
#      total_phenols  flavanoids  nonflavanoid_phenols  proanthocyanins  \
# 0         0.806722    1.031908             -0.657708         1.221438
# 1         0.567048    0.731565             -0.818411        -0.543189
# 2         0.806722    1.212114             -0.497005         2.129959
# 3         2.484437    1.462399             -0.979113         1.029251
# 4         0.806722    0.661485              0.226158         0.400275
# ..             ...         ...                   ...              ...
# 173      -0.982841   -1.420891              1.270726        -0.927563
# 174      -0.791103   -1.280731              0.547563        -0.316058
# 175      -1.126646   -1.340800              0.547563        -0.420888
# 176      -1.030776   -1.350811              1.351077        -0.228701
# 177      -0.391646   -1.270720              1.592131        -0.420888
#
#      color_intensity       hue  od280/od315_of_diluted_wines   proline
# 0           0.251009  0.361158                      1.842721  1.010159
# 1          -0.292496  0.404908                      1.110317  0.962526
# 2           0.268263  0.317409                      0.786369  1.391224
# 3           1.182732 -0.426341                      1.180741  2.328007
# 4          -0.318377  0.361158                      0.448336 -0.037767
# ..               ...       ...                           ...       ...
# 173         1.139596 -1.388840                     -1.227742 -0.021890
# 174         0.967055 -1.126341                     -1.481267  0.009866
# 175         2.217979 -1.607590                     -1.481267  0.279786
# 176         1.829761 -1.563840                     -1.396759  0.295664
# 177         1.786626 -1.520090                     -1.424928 -0.593486
#
# [178 rows x 13 columns]

# %%
num_features = df.shape[1]
print("Количество признаков:", num_features)
# Out:
# Количество признаков: 13

# %%
import matplotlib.pyplot as plt

wine = sklearn.datasets.load_wine()
 
X = wine.data 
y = wine.target  

X = (X - X.mean(axis=0))/X.std(axis=0)

data = np.column_stack((X, y))
data = torch.tensor(data, dtype=torch.float32)

train = data[:130]
valid = data[130:150]
test = data[150:]

plt.scatter(X[:, 0], X[:, 1], c = y, cmap = 'viridis')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('Wine')
plt.show()

# %%
# делим данные на трейн, валидацию и тест
X_train_valid, X_test, y_train_valid, y_test = train_test_split(df_normalized.values, target.values, test_size = 0.2, random_state = 42)
X_train, X_val, y_train, y_val = train_test_split(X_train_valid, y_train_valid, test_size = 0.2, random_state = 42)

# надо преобразовать данные в тензоры
X_train_tensor = torch.tensor(X_train, dtype = torch.float32)
y_train_tensor = torch.tensor(y_train, dtype = torch.float32)

X_val_tensor = torch.tensor(X_val, dtype = torch.float32)
y_val_tensor = torch.tensor(y_val, dtype = torch.float32)

X_test_tensor = torch.tensor(X_test, dtype = torch.float32)
y_test_tensor = torch.tensor(y_test, dtype = torch.float32)

# %%
# создаем модель нейронной сети
class WineClassifier(nn.Module):
    def __init__(self):
        super(WineClassifier, self).__init__()
        self.fc1 = nn.Linear(13, 64)
        self.relu1 = nn.ReLU()
        self.fc2 = nn.Linear(64, 32)
        self.relu2 = nn.ReLU()
        self.fc3 = nn.Linear(32, 3)  # так как 3 класса в df

    def forward(self, x):
        x = self.relu1(self.fc1(x))
        x = self.relu2(self.fc2(x))
        x = self.fc3(x)
        return x

# %%
def train_and_evaluate(model, X_train, y_train, X_val, y_val, X_test, y_test, optimizer, loss_fn, batch_size, epochs):
    val_losses = []
    val_accuracy = []
    
    train_dataset = TensorDataset(X_train, y_train)
    train_loader = DataLoader(train_dataset, batch_size = batch_size, shuffle = True)

    for epoch in range(epochs):
        model.train()
        for X_batch, y_batch in train_loader:
            optimizer.zero_grad()
            out = model(X_batch)
            loss = loss_fn(out, torch.argmax(y_batch, dim=1))
            loss.backward()
            optimizer.step()

        model.eval()
        with torch.no_grad():
            val_out = model(X_val)
            val_loss = loss_fn(val_out, torch.argmax(y_val, dim=1))
            val_losses.append(val_loss.item())
            val_acc = (torch.argmax(val_out, dim = 1) == torch.argmax(y_val, dim = 1)).float().mean().item()
            val_accuracy.append(val_acc)

    # Оценка модели на тесте
    model.eval()
    with torch.no_grad():
        test_out = model(X_test)
        test_loss = loss_fn(test_out, torch.argmax(y_test, dim = 1))
        test_accuracy = (torch.argmax(test_out, dim = 1) == torch.argmax(y_test, dim = 1)).float().mean().item()

    print(f'Test Loss: {test_loss.item():.3f}, Test Accuracy: {test_accuracy:.3f}')

    return val_losses, val_accuracy, test_loss.item(), test_accuracy

# %%
model_w = WineClassifier()

loss_fn = nn.CrossEntropyLoss()
optimizer = optim.Adam(model_w.parameters(), lr=0.001)

val_losses, val_accuracy, test_loss, test_accuracy = train_and_evaluate(model_w, 
                                                                        X_train_tensor, y_train_tensor, 
                                                                        X_val_tensor, y_val_tensor, 
                                                                        X_test_tensor, y_test_tensor, 
                                                                        optimizer, 
                                                                        loss_fn, 
                                                                        32, 
                                                                        100)
# Out:
# Test Loss: 0.003, Test Accuracy: 1.000
